# %%
#Import environment and libraries
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from unidecode import unidecode

# %%
#Load CSV File as Pandas DataFrame & Preview DF
df = pd.read_csv(Path('./Final_Project_MASAS-main/Resources/Static Data/combined_csv.csv'))
df.head()
# Out:
#                       Primary_Key School_Name           Test_Score  \
# 0  Aldine_ISD_Grade 3 Mathematics  Aldine_ISD  Grade 3 Mathematics
# 1  Aldine_ISD_Grade 3 Mathematics  Aldine_ISD  Grade 3 Mathematics
# 2  Aldine_ISD_Grade 3 Mathematics  Aldine_ISD  Grade 3 Mathematics
# 3  Aldine_ISD_Grade 3 Mathematics  Aldine_ISD  Grade 3 Mathematics
# 4  Aldine_ISD_Grade 3 Mathematics  Aldine_ISD  Grade 3 Mathematics
#
#   STAAR Performance Rates by Tested Grade, Subject, and Performance Level  \
# 0                             At Masters Grade Level
# 1                             At Masters Grade Level
# 2                 At Approaches Grade Level or Above
# 3                 At Approaches Grade Level or Above
# 4                      At Meets Grade Level or Above
#
#   School_Year  YoY_State  State  YoY_Region  Region_04  YoY_District  ...  \
# 0   2021_2022       0.07   0.21        0.07       0.22          0.04  ...
# ...

# %%
# Determine variable we want to predict -- YOY Scores for ELL students
y = df["YoY_ELL"]
X = df.drop(columns="YoY_ELL")

# %%
# Split variables into training set (larger portion of data, 70%+) and test set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                                   y,
                                                   random_state=1,
                                                   stratify=y)
X_train.shape
# Out:
# (1129, 20)

# %%
# Initialize and Train Model using training sets (X_train & y_train)
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                               max_iter=200,
                               random_state=1)

# %%
try_data = df
for col in ['Primary_Key']:
    try_data[col] = try_data[col].apply(unidecode)

# %%
#Test by calling Predict Method & giving the X_test variable as argument
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3024\3772637832.py in <module>
#       1 #Test by calling Predict Method & giving the X_test variable as argument
# ----> 2 classifier.fit(X_train, y_train)
#
# ~\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# ~\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# ...

# %%
#Predictions compared to results in y_test set
# y_pred = classifier.predict(X_test)
#results = pd.DataFrame({"Prediction": y_pred, "Actual": y_test}).reset_index(drop=True)
#results.head(20)

# %%
# Assess performance of model with results
#from sklearn.metrics import accuracy_score
#print(accuracy_score(y_test, y_pred))
